# %% [markdown]
# # Step 1: Importing necessary libraries

# %%
#Importing libraries
import re
import pandas as pd

# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(8, 6), dpi=80)

from pandas import DataFrame 
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LogisticRegression
from sklearn import neighbors
from scipy.spatial.distance import cosine
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

import re
import string
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Step 2: Reading the Dataset

# %%
df = pd.read_json('./Data/Prime_Pantry.json', lines=True) #with pandas
df.head() #displaying top 5 rows
# Out:
#    overall  verified   reviewTime      reviewerID        asin  \
# 0        5      True  12 14, 2014  A1NKJW0TNRVS7O  B0000DIWNZ
# 1        4      True  11 20, 2014  A2L6X37E8TFTCC  B0000DIWNZ
# 2        4      True  10 11, 2014  A2WPR4W6V48121  B0000DIWNZ
# 3        3     False   09 1, 2014  A27EE7X7L29UMU  B0000DIWNZ
# 4        4      True  08 10, 2014  A1OWT4YZGB5GV9  B0000DIWNZ
#
#       reviewerName                                         reviewText  \
# 0        Tamara M.                                      Good clinging
# 1  Amazon Customer  Fantastic buy and a good plastic wrap.  Even t...
# 2           noname                                                 ok
# 3           ZapNZs  Saran Cling Plus is kind of like most of the C...
# 4       Amy Rogers  This is my go to plastic wrap so there isn't m...
#
#                                              summary  unixReviewTime vote  \
# 0                                       Clings  well      1418515200  NaN
# 1         Saran could use more Plus to Cling better.      1416441600  NaN
# 2                                         Four Stars      1412985600  NaN
# 3  The wrap is fantastic, but the dispensing, cut...      1409529600    4
# 4                  has been doing it's job for years      1407628800  NaN
#
#   image style
# 0   NaN   NaN
# 1   NaN   NaN
# 2   NaN   NaN
# 3   NaN   NaN
# 4   NaN   NaN

# %%
#checking the shape of data
df.shape
# Out:
# (471614, 12)

# %% [markdown]
# # Step 3: Dataset pre-processing
# > Performing product based colloborative filtering

# %%
#grouping by on product id (which is asin) on bases of count and mean
grp_count = df.groupby("asin", as_index=False).count()


#joining the dataframes
df_joined = pd.merge(df, grp_count, how='right', on=['asin'])
df_joined.head()
# Out:
#    overall_x  verified_x reviewTime_x    reviewerID_x        asin  \
# 0          2       False  09 20, 2017   A2HZ0F1Q8CVX1  B00005BPJO
# 1          3        True  03 23, 2016  A3C4FVGQ0FSORL  B00005BPJO
# 2          4       False  07 17, 2015  A2582KMXLK2P06  B00005BPJO
# 3          5        True  05 30, 2015  A1CSVASI7B3RTX  B00005BPJO
# 4          5       False  10 13, 2014  A2K7V3G4598QRF  B00005BPJO
#
#     reviewerName_x                                       reviewText_x  \
# 0  Heather Haskins  The outside of them is wet and sticky.. like t...
# 1   Amazon shopper                                    They came white
# 2            Bryan  I used to hate Milk Duds for the longest time,...
# 3            Sadie                                          Very good
# 4       Daydreamer  I love these. The chocolate is really good and...
#
#                 summary_x  unixReviewTime_x vote_x  ... verified_y  \
# 0        Sticky and stale        1505865600    NaN  ...         10
# 1             Three Stars        1458691200    NaN  ...         10
# 2     milky deliciousness        1437091200      2  ...         10
# 3              Five Stars        1432944000      2  ...         10
# 4  These are really good.        1413158400    NaN  ...         10
#
#   reviewTime_y  reviewerID_y  reviewerName_y  reviewText_y  summary_y  \
# 0           10            10              10            10         10
# 1           10            10              10            10         10
# 2           10            10              10            10         10
# 3           10            10              10            10         10
# 4           10            10              10            10         10
#
#    unixReviewTime_y  vote_y  image_y  style_y
# 0                10       7        0        0
# 1                10       7        0        0
# 2                10       7        0        0
# 3                10       7        0        0
# 4                10       7        0        0
#
# [5 rows x 23 columns]

# %%
#renaming columns
df_joined["num_reviewers"] = df_joined["reviewerID_y"]
df_joined["total_score"] = df_joined["overall_x"]
df_joined["review_summary"] = df_joined["summary_x"]

#making a new df containing just three columns
df_final = df_joined[['asin','review_summary','total_score',"num_reviewers"]]

# %%
df_joined["num_reviewers"].value_counts()[:20].plot(kind='barh', grid=True , color='lightcoral')
plt.xlabel('Number of Products')
plt.ylabel('Number of Reviewers')
plt.title('Top 20 Products with the Most Reviewers', fontweight="bold")
plt.show()

# %%
#selecting reviews which were reviewed by more than 80 users
df_joined = df_joined.sort_values(by='num_reviewers', ascending=False)
df_joined_above_80 = df_joined[df_joined.num_reviewers >= 80]
df_joined_above_80.head()
# Out:
#        overall_x  verified_x reviewTime_x    reviewerID_x        asin  \
# 95168          5        True  03 18, 2018  A3Q7NGN14THEQN  B00I3MVY9I
# 97253          5        True  04 30, 2016  A1HK96JOR9S41X  B00I3MVY9I
# 97243          5        True   05 2, 2016  A3TS3EHK165MUY  B00I3MVY9I
# 97244          5        True   05 2, 2016  A3LDY0IZFH8URP  B00I3MVY9I
# 97245          4        True   05 2, 2016  A32QY0TB7B6R73  B00I3MVY9I
#
#          reviewerName_x                                       reviewText_x  \
# 95168           Sichuan  I was surprised at how well this worked. I thi...
# 97253             A.E.I  Love this product. I can't already see a chang...
# 97243  Siri Amrit Ramos  Great! Just what you'd expect. Does make my te...
# 97244   Amazon Customer  My teeth are looking so much better thanks to ...
# 97245              AudC  I was expecting a dramatic difference based on...
#
#                                  summary_x  unixReviewTime_x vote_x  ...  \
# 95168                           Effective!        1521331200    NaN  ...
# 97253                           Five Stars        1461974400    NaN  ...
# 97243               Shiny teeth for months        1462147200    NaN  ...
# 97244                    It actually works        1462147200    NaN  ...
# 97245  Although I'm happy with the results        1462147200    NaN  ...
#
#       reviewerName_y reviewText_y  summary_y  unixReviewTime_y  vote_y  \
# 95168           6535         6527       6537              6537     536
# 97253           6535         6527       6537              6537     536
# 97243           6535         6527       6537              6537     536
# 97244           6535         6527       6537              6537     536
# 97245           6535         6527       6537              6537     536
#
#        image_y  style_y  num_reviewers  total_score  \
# 95168       89        0           6537            5
# 97253       89        0           6537            5
# 97243       89        0           6537            5
# 97244       89        0           6537            5
# 97245       89        0           6537            4
#
#                             review_summary
# 95168                           Effective!
# 97253                           Five Stars
# 97243               Shiny teeth for months
# 97244                    It actually works
# 97245  Although I'm happy with the results
#
# [5 rows x 26 columns]

# %%
df_joined_above_80["num_reviewers"].value_counts()[:20].plot(kind='barh', grid=True , color='lightcoral')
plt.xlabel('Number of Products')  
plt.ylabel('Number of Reviewers')  
plt.title('Top 20 Products with the Most Reviewers (Reviewed by more than 80 users)', fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Top 20 Products with the Most Reviewers (Reviewed by more than 80 users)')

# %%
#making final product reviews dataset
df_product = df.groupby("asin", as_index=False).mean()
df_product_review = df_joined_above_80.groupby("asin")["review_summary"].apply(list)
df_product_review = pd.DataFrame(df_product_review)
df_product_review.to_csv("appliances_product_summary.csv")
# Out:
# /var/folders/dd/0k6q11nj127933sr8wm11nhw0000gn/T/ipykernel_63593/1709824845.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_product = df.groupby("asin", as_index=False).mean()

# %%
df_product_review.head()
# Out:
#                                                review_summary
# asin
# B00032E8XK  [Five Stars, Good Tasting Tuna - Recommended, ...
# B00099XLXU  [One Star, Bottom of 1 of containers was not i...
# B00099XNXS  [Not as good as I remembered as a kid, Four St...
# B00099XO3W  [Five Stars, Favorite tomato soup, Four Stars,...
# B00099XO50  [Five Stars, Five Stars, Love 'Em!, Pantry sta...

# %%
#merging
df_product_review = pd.read_csv("appliances_product_summary.csv")
df_product_review = pd.merge(df_product_review, df_product, on="asin", how='inner')

# %%
df_product_review = df_product_review[['asin','review_summary','overall']]
df_product_review.head()
# Out:
#          asin                                     review_summary   overall
# 0  B00032E8XK  ['Five Stars', 'Good Tasting Tuna - Recommende...  4.100418
# 1  B00099XLXU  ['One Star', 'Bottom of 1 of containers was no...  4.439189
# 2  B00099XNXS  ['Not as good as I remembered as a kid', 'Four...  4.209596
# 3  B00099XO3W  ['Five Stars', 'Favorite tomato soup', 'Four S...  4.244444
# 4  B00099XO50  ['Five Stars', 'Five Stars', "Love 'Em!", 'Pan...  4.224719

# %%
df_ranges = pd.crosstab(df_product_review['asin'], pd.cut(df_product_review['overall'], [2, 2.5, 3.0, 3.5, 4.0, 4.5, 5]))
df_ranges.head()
# Out:
# overall     (2.0, 2.5]  (2.5, 3.0]  (3.0, 3.5]  (3.5, 4.0]  (4.0, 4.5]  \
# asin
# B00032E8XK           0           0           0           0           1
# B00099XLXU           0           0           0           0           1
# B00099XNXS           0           0           0           0           1
# B00099XO3W           0           0           0           0           1
# B00099XO50           0           0           0           0           1
#
# overall     (4.5, 5.0]
# asin
# B00032E8XK           0
# B00099XLXU           0
# B00099XNXS           0
# B00099XO3W           0
# B00099XO50           0

# %%
df_ranges.sum().sort_values(ascending=False).plot.bar(color='lightcoral', figsize=(10, 6))
plt.xlabel('Overall Rating Ranges')
plt.ylabel('Number of Products')
plt.title('Distribution of Overall Ratings for Products', fontweight="bold")
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
df['overall'].value_counts().sort_index().plot(kind='bar', color='lightcoral', figsize=(8, 6))
plt.xlabel('Overall Rating')
plt.ylabel('Number of Reviews')
plt.title('Distribution of Overall Ratings in the Dataset', fontweight="bold")
plt.show()

# %% [markdown]
# # Step 4: Text Cleaning

# %%
#tokenizing text
reg = re.compile('[^a-z]+')
def cleanText(text):
    text = text.lower()
    text = reg.sub(' ', text).strip()
    return text

# %%
#drop duplicate rows
df_product_review["cleaned_review"] = df_product_review["review_summary"].apply(cleanText)
df_product_review = df_product_review.drop_duplicates(['overall'], keep='last')
df_product_review = df_product_review.reset_index()

# %%
#count vectorization
reviews = df_product_review["cleaned_review"] 
countVector = CountVectorizer(max_features = 200, stop_words='english') 
transformed_reviews = countVector.fit_transform(reviews) 

df_reviews = DataFrame(transformed_reviews.A, columns=countVector.get_feature_names_out())
df_reviews = df_reviews.astype(int)

# %%
#save 
df_reviews.to_csv("appliances_reviews.csv")

# %% [markdown]
# # Step 5: Train Test Split

# %%
X = np.array(df_reviews)
train_test_ratio = 0.9
size = int(np.floor(train_test_ratio * len(X)))
X_train = X[:size]
X_test = X[size:]

# %%
neighbor = NearestNeighbors(n_neighbors=3, algorithm='ball_tree').fit(X_train)
distances, indices = neighbor.kneighbors(X_train)

# %% [markdown]
# # Step 6: Finding related products
# > Uses the Nearest Neighbors algorithm to find similar products based on their reviews.

# %%
#find most related products
for i in range(len(X_test)):
    product_test = neighbor.kneighbors([X_test[i]])
    related_products = product_test[1]

    related_product_1 = [item[0] for item in related_products]
    related_product_1 = str(related_product_1).strip('[]')
    related_product_1 = int(related_product_1)
    
    related_product_2 = [item[1] for item in related_products]
    related_product_2 = str(related_product_2).strip('[]')
    related_product_2 = int(related_product_2)
    
    print ("Based on product reviews, for ", df_product_review["asin"][len(X_train) + i] ," average rating is ",df_product_review["overall"][len(X_train) + i])
    print ("The first similar product is ", df_product_review["asin"][related_product_1] ," average rating is ",df_product_review["overall"][related_product_1])
    print ("The second similar product is ", df_product_review["asin"][related_product_2] ," average rating is ",df_product_review["overall"][related_product_2])
    print ("-----------------------------------------------------------")
# Out:
# Based on product reviews, for  B01890O0K8  average rating is  3.752577319587629
# The first similar product is  B00I8GMBDW  average rating is  4.348314606741573
# The second similar product is  B010NE4U08  average rating is  4.086206896551724
# -----------------------------------------------------------
# Based on product reviews, for  B01892J858  average rating is  4.205128205128205
# The first similar product is  B00N0WZSOS  average rating is  4.038461538461538
# The second similar product is  B015O6PSO2  average rating is  4.329831932773109
# -----------------------------------------------------------
# Based on product reviews, for  B018E4UPYY  average rating is  3.2268041237113403
# The first similar product is  B00QJGT51E  average rating is  2.7373737373737375
# The second similar product is  B00QJGWAU2  average rating is  2.1744186046511627
# -----------------------------------------------------------
# Based on product reviews, for  B018FRY5X2  average rating is  4.815533980582524
# The first similar product is  B016DHCJP2  average rating is  4.34375
# The second similar product is  B00JQQAS0G  average rating is  4.690476190476191
# -----------------------------------------------------------
# Based on product reviews, for  B018FRZO6E  average rating is  4.438095238095238
# The first similar product is  B00OP1F0R8  average rating is  4.827160493827161
# The second similar product is  B00R1H0KQO  average rating is  4.285714285714286
# -----------------------------------------------------------
# Based on product reviews, for  B018FS0PXA  average rating is  4.785714285714286
# The first similar product is  B00Z9ZUT8E  average rating is  4.134146341463414
# The second similar product is  B00V1OFAN6  average rating is  4.481481481481482
# -----------------------------------------------------------
# Based on product reviews, for  B018FS0V52  average rating is  4.779816513761468
# The first similar product is  B016DHCJP2  average rating is  4.34375
# The second similar product is  B00ZBK65GM  average rating is  4.528
# -----------------------------------------------------------
# Based on product reviews, for  B018FS0XGE  average rating is  4.440860215053763
# The first similar product is  B00TWZRQX8  average rating is  4.158536585365853
# The second similar product is  B00VYUBQDK  average rating is  4.4523809523809526
# -----------------------------------------------------------
# Based on product reviews, for  B018FS0ZYO  average rating is  4.534090909090909
# The first similar product is  B000OUYNC2  average rating is  4.698795180722891
# The second similar product is  B00V1PAQZW  average rating is  4.4941176470588236
# -----------------------------------------------------------
# Based on product reviews, for  B018FS1AUC  average rating is  4.558333333333334
# The first similar product is  B00R1H0V18  average rating is  4.711111111111111
# The second similar product is  B00PC5CRGI  average rating is  4.305785123966942
# -----------------------------------------------------------
# Based on product reviews, for  B018FVNFRU  average rating is  4.495145631067961
# The first similar product is  B010NBFHFS  average rating is  4.287356321839081
# The second similar product is  B000RK4BFI  average rating is  4.584615384615384
# -----------------------------------------------------------
# Based on product reviews, for  B018YI6JXQ  average rating is  4.817073170731708
# The first similar product is  B00X80113O  average rating is  4.5964912280701755
# The second similar product is  B00VTUQH8O  average rating is  3.926829268292683
# -----------------------------------------------------------
# Based on product reviews, for  B018YI6QHA  average rating is  4.858695652173913
# The first similar product is  B00X80113O  average rating is  4.5964912280701755
# The second similar product is  B000PL0YG4  average rating is  4.528455284552845
# -----------------------------------------------------------
# Based on product reviews, for  B0195VBFFI  average rating is  3.8031496062992125
# The first similar product is  B010O74CHA  average rating is  4.5058823529411764
# The second similar product is  B0132ZPJSC  average rating is  4.7075471698113205
# -----------------------------------------------------------
# Based on product reviews, for  B0195VBXEQ  average rating is  3.83206106870229
# The first similar product is  B0108105BY  average rating is  4.24468085106383
# The second similar product is  B00YOQY3L8  average rating is  3.8191489361702127
# -----------------------------------------------------------
# Based on product reviews, for  B019627ESI  average rating is  4.723684210526316
# The first similar product is  B0142WCKIG  average rating is  4.70945945945946
# The second similar product is  B00UJIVHVE  average rating is  4.733870967741935
# -----------------------------------------------------------
# Based on product reviews, for  B019627HGM  average rating is  4.579439252336448
# The first similar product is  B00I669J5W  average rating is  4.7682926829268295
# The second similar product is  B014GJYB4Q  average rating is  4.337078651685394
# -----------------------------------------------------------
# Based on product reviews, for  B0196H6RGI  average rating is  3.5121951219512195
# The first similar product is  B00NAZ48VO  average rating is  4.022471910112359
# The second similar product is  B00MHTDKBI  average rating is  4.345679012345679
# -----------------------------------------------------------
# Based on product reviews, for  B0196H6Y02  average rating is  4.045977011494253
# The first similar product is  B00UB6SWRG  average rating is  3.7555555555555555
# The second similar product is  B00VTUQH8O  average rating is  3.926829268292683
# -----------------------------------------------------------
# Based on product reviews, for  B0197U2QOQ  average rating is  4.313253012048193
# The first similar product is  B00MHTDKBI  average rating is  4.345679012345679
# The second similar product is  B000VK2MGO  average rating is  4.113636363636363
# -----------------------------------------------------------
# Based on product reviews, for  B01981KS8U  average rating is  4.251497005988024
# The first similar product is  B00NNZQJAO  average rating is  4.2398081534772185
# The second similar product is  B00NO037D0  average rating is  4.291666666666667
# -----------------------------------------------------------
# Based on product reviews, for  B019DKRFO6  average rating is  4.4485981308411215
# The first similar product is  B013SRDRBA  average rating is  4.323529411764706
# The second similar product is  B010CRFSTI  average rating is  4.411111111111111
# -----------------------------------------------------------
# Based on product reviews, for  B019FFOPVU  average rating is  4.690140845070423
# The first similar product is  B00Z9YWAO6  average rating is  4.434782608695652
# The second similar product is  B00SWRZLT8  average rating is  4.492063492063492
# -----------------------------------------------------------
# Based on product reviews, for  B019IK3A36  average rating is  4.330985915492958
# The first similar product is  B0185LXKPW  average rating is  4.52808988764045
# The second similar product is  B00UOLAELU  average rating is  4.318681318681318
# -----------------------------------------------------------
# Based on product reviews, for  B019KE3616  average rating is  4.204301075268817
# The first similar product is  B00Z9ZUT8E  average rating is  4.134146341463414
# The second similar product is  B012F2QI6K  average rating is  4.130434782608695
# -----------------------------------------------------------
# Based on product reviews, for  B019KE3620  average rating is  4.346534653465347
# The first similar product is  B00O0ZUZVA  average rating is  4.321428571428571
# The second similar product is  B00VFZ2P5C  average rating is  4.296296296296297
# -----------------------------------------------------------
# Based on product reviews, for  B019KE37KQ  average rating is  4.392156862745098
# The first similar product is  B010FAU8MO  average rating is  4.7727272727272725
# The second similar product is  B010NBFHFS  average rating is  4.287356321839081
# -----------------------------------------------------------
# Based on product reviews, for  B019KE37WO  average rating is  4.424242424242424
# The first similar product is  B010NBFHFS  average rating is  4.287356321839081
# The second similar product is  B00ID0DVYQ  average rating is  4.114285714285714
# -----------------------------------------------------------
# Based on product reviews, for  B019XEY5GS  average rating is  4.642184557438795
# The first similar product is  B00NAZ5RIC  average rating is  4.689090909090909
# The second similar product is  B00UBJQHMU  average rating is  4.711240310077519
# -----------------------------------------------------------
# Based on product reviews, for  B019XGVHYE  average rating is  4.34
# The first similar product is  B00RBPZN6S  average rating is  4.142857142857143
# The second similar product is  B013QN6SNA  average rating is  4.465116279069767
# -----------------------------------------------------------
# Based on product reviews, for  B019XQI3JQ  average rating is  3.903225806451613
# The first similar product is  B00SMYMTOG  average rating is  4.154761904761905
# The second similar product is  B012F2QI6K  average rating is  4.130434782608695
# -----------------------------------------------------------
# Based on product reviews, for  B01A5GQ192  average rating is  4.704697986577181
# The first similar product is  B00IT70RFO  average rating is  4.584905660377358
# The second similar product is  B00WFVWK2S  average rating is  4.635802469135802
# -----------------------------------------------------------
# Based on product reviews, for  B01A6NXQQU  average rating is  4.105882352941176
# The first similar product is  B00VWH6ITW  average rating is  3.5294117647058822
# The second similar product is  B00WS3X50O  average rating is  4.308641975308642
# -----------------------------------------------------------
# Based on product reviews, for  B01AG167XG  average rating is  4.359154929577465
# The first similar product is  B00RGL7EAA  average rating is  4.5423728813559325
# The second similar product is  B00UFUZTQK  average rating is  4.536
# -----------------------------------------------------------
# Based on product reviews, for  B01AHTC7PO  average rating is  3.9741935483870967
# The first similar product is  B00NB2M2F0  average rating is  3.8359375
# The second similar product is  B00VJYSGAM  average rating is  4.4480519480519485
# -----------------------------------------------------------
# Based on product reviews, for  B01AHVB75I  average rating is  4.0
# The first similar product is  B00VV4VS82  average rating is  4.104166666666667
# The second similar product is  B00WS2QQME  average rating is  3.75
# -----------------------------------------------------------
# Based on product reviews, for  B01B4I1BOA  average rating is  4.021505376344086
# The first similar product is  B00UOLCK4E  average rating is  4.540229885057471
# The second similar product is  B00UB70JTY  average rating is  4.009803921568627
# -----------------------------------------------------------
# Based on product reviews, for  B01B4LHETI  average rating is  3.9591836734693877
# The first similar product is  B002DO19JC  average rating is  4.554216867469879
# The second similar product is  B00X3G7GUK  average rating is  4.346938775510204
# -----------------------------------------------------------
# Based on product reviews, for  B01B4N9Y6C  average rating is  3.7042716319824756
# The first similar product is  B00JGZBTCI  average rating is  4.602649006622516
# The second similar product is  B00PC5CI8K  average rating is  4.5586457073760585
# -----------------------------------------------------------
# Based on product reviews, for  B01B5KQCCS  average rating is  4.223300970873787
# The first similar product is  B00O0ZUZVA  average rating is  4.321428571428571
# The second similar product is  B00ZTNKJJK  average rating is  4.063157894736842
# -----------------------------------------------------------
# Based on product reviews, for  B01B5Q8L30  average rating is  3.8137254901960786
# The first similar product is  B000VCD86A  average rating is  4.12037037037037
# The second similar product is  B00I8G6GW4  average rating is  4.2555555555555555
# -----------------------------------------------------------
# Based on product reviews, for  B01B5Q8NII  average rating is  3.639344262295082
# The first similar product is  B00V78208Y  average rating is  4.366336633663367
# The second similar product is  B0010XRZ7W  average rating is  4.523809523809524
# -----------------------------------------------------------
# Based on product reviews, for  B01B5Q8ZYA  average rating is  2.943820224719101
# The first similar product is  B00QJGT51E  average rating is  2.7373737373737375
# The second similar product is  B015IO2JR4  average rating is  3.142857142857143
# -----------------------------------------------------------
# Based on product reviews, for  B01B630QFS  average rating is  3.740740740740741
# The first similar product is  B00V1PAQZW  average rating is  4.4941176470588236
# The second similar product is  B00V1P7V0A  average rating is  4.282828282828283
# -----------------------------------------------------------
# Based on product reviews, for  B01B7L10ZE  average rating is  4.476744186046512
# The first similar product is  B00UB77PQO  average rating is  4.295454545454546
# The second similar product is  B00V1PAQZW  average rating is  4.4941176470588236
# -----------------------------------------------------------
# Based on product reviews, for  B01B7L2F62  average rating is  4.579710144927536
# The first similar product is  B000Q5G7KG  average rating is  4.4465648854961835
# The second similar product is  B000RY6G3E  average rating is  4.245353159851301
# -----------------------------------------------------------
# Based on product reviews, for  B01BGDZJGE  average rating is  4.3478260869565215
# The first similar product is  B00T7PG422  average rating is  4.5092592592592595
# The second similar product is  B00O33EZLU  average rating is  4.548022598870056
# -----------------------------------------------------------
# Based on product reviews, for  B01BGEGK0M  average rating is  3.4127659574468083
# The first similar product is  B00Q8JIN7O  average rating is  4.44949494949495
# The second similar product is  B00NJ1MALE  average rating is  4.660130718954249
# -----------------------------------------------------------
# Based on product reviews, for  B01BGJ5LS4  average rating is  4.5625
# The first similar product is  B00UB7BGE6  average rating is  4.762886597938144
# The second similar product is  B00NAZ55Q6  average rating is  4.677248677248677
# -----------------------------------------------------------
# Based on product reviews, for  B01BK9MVF6  average rating is  4.52
# The first similar product is  B00O7TNXT0  average rating is  4.287037037037037
# The second similar product is  B010Q32WWY  average rating is  3.80188679245283
# -----------------------------------------------------------
# Based on product reviews, for  B01BK9MXZE  average rating is  4.428571428571429
# The first similar product is  B00J2AV5MG  average rating is  4.543130990415335
# The second similar product is  B000Q5K1RG  average rating is  4.360881542699724
# -----------------------------------------------------------
# Based on product reviews, for  B01BK9O3D4  average rating is  4.450549450549451
# The first similar product is  B00QJGS0OM  average rating is  3.849462365591398
# The second similar product is  B012W3AI9K  average rating is  4.185185185185185
# -----------------------------------------------------------
# Based on product reviews, for  B01BKBWF3W  average rating is  4.670731707317073
# The first similar product is  B00TFR9MT4  average rating is  4.195652173913044
# The second similar product is  B010NBIT6W  average rating is  4.440476190476191
# -----------------------------------------------------------
# Based on product reviews, for  B01C3XGYWO  average rating is  4.666666666666667
# The first similar product is  B00I9KRX3A  average rating is  4.3580246913580245
# The second similar product is  B00099XO50  average rating is  4.224719101123595
# -----------------------------------------------------------
# Based on product reviews, for  B01C3XH6W6  average rating is  4.7227722772277225
# The first similar product is  B00QTM03A0  average rating is  4.46218487394958
# The second similar product is  B00J4YYMES  average rating is  4.55
# -----------------------------------------------------------
# Based on product reviews, for  B01C3XHEQO  average rating is  4.669354838709677
# The first similar product is  B00I2X7KZA  average rating is  4.531914893617022
# The second similar product is  B00QTM1C82  average rating is  4.63302752293578
# -----------------------------------------------------------
# Based on product reviews, for  B01C3XHYGO  average rating is  4.580487804878048
# The first similar product is  B00I3N3L66  average rating is  4.519607843137255
# The second similar product is  B000S5TIPK  average rating is  4.355450236966824
# -----------------------------------------------------------
# Based on product reviews, for  B01C3XIQDE  average rating is  4.585365853658536
# The first similar product is  B00UB70JTY  average rating is  4.009803921568627
# The second similar product is  B010D0176C  average rating is  4.62962962962963
# -----------------------------------------------------------
# Based on product reviews, for  B01C5IF8MY  average rating is  4.6909090909090905
# The first similar product is  B014GJYB4Q  average rating is  4.337078651685394
# The second similar product is  B017DF6II2  average rating is  4.2682926829268295
# -----------------------------------------------------------
# Based on product reviews, for  B01C5IGWZQ  average rating is  4.707865168539326
# The first similar product is  B00UB77PQO  average rating is  4.295454545454546
# The second similar product is  B00V1PAQZW  average rating is  4.4941176470588236
# -----------------------------------------------------------
# Based on product reviews, for  B01C5RARTY  average rating is  4.11578947368421
# The first similar product is  B00MOJUKH8  average rating is  4.808988764044944
# The second similar product is  B00Z9ZUT8E  average rating is  4.134146341463414
# -----------------------------------------------------------
# Based on product reviews, for  B01C6QTWKO  average rating is  3.764705882352941
# The first similar product is  B00RGNGQMU  average rating is  3.921259842519685
# The second similar product is  B010NBFHFS  average rating is  4.287356321839081
# -----------------------------------------------------------
# Based on product reviews, for  B01C6QTYZC  average rating is  4.230769230769231
# The first similar product is  B00RGL7EAA  average rating is  4.5423728813559325
# The second similar product is  B00R1H0V18  average rating is  4.711111111111111
# -----------------------------------------------------------
# Based on product reviews, for  B01C6QU58C  average rating is  4.393258426966292
# The first similar product is  B00V1P7V0A  average rating is  4.282828282828283
# The second similar product is  B00I669J5W  average rating is  4.7682926829268295
# -----------------------------------------------------------
# Based on product reviews, for  B01C6QUJ5G  average rating is  4.5576923076923075
# The first similar product is  B017NF3D6C  average rating is  4.64748201438849
# The second similar product is  B00X71HY8A  average rating is  4.5863874345549736
# -----------------------------------------------------------
# Based on product reviews, for  B01C6QUWMQ  average rating is  4.61
# The first similar product is  B00I8GGA9I  average rating is  4.1826923076923075
# The second similar product is  B00I9VC3UM  average rating is  4.3875
# -----------------------------------------------------------
# Based on product reviews, for  B01C6Y6R7W  average rating is  4.455445544554456
# The first similar product is  B00R1CRSWI  average rating is  4.757009345794392
# The second similar product is  B00R1CS3CM  average rating is  4.74
# -----------------------------------------------------------
# Based on product reviews, for  B01C6Y6U8I  average rating is  4.642857142857143
# The first similar product is  B00UB77PQO  average rating is  4.295454545454546
# The second similar product is  B013QN6SNA  average rating is  4.465116279069767
# -----------------------------------------------------------
# Based on product reviews, for  B01C6Y79NS  average rating is  4.510791366906475
# The first similar product is  B00UB7D60I  average rating is  4.659259259259259
# The second similar product is  B00JGZBUPE  average rating is  4.692913385826771
# -----------------------------------------------------------
# Based on product reviews, for  B01COSHFG2  average rating is  4.255813953488372
# The first similar product is  B000SRGDJ2  average rating is  4.406976744186046
# The second similar product is  B000VDUV00  average rating is  4.112359550561798
# -----------------------------------------------------------
# Based on product reviews, for  B01COSTTUC  average rating is  3.891566265060241
# The first similar product is  B00OP1F0R8  average rating is  4.827160493827161
# The second similar product is  B00Z9ZUT8E  average rating is  4.134146341463414
# -----------------------------------------------------------
# Based on product reviews, for  B01COSU2VM  average rating is  4.270833333333333
# The first similar product is  B00V78208Y  average rating is  4.366336633663367
# The second similar product is  B00WX4259A  average rating is  4.436781609195402
# -----------------------------------------------------------
# Based on product reviews, for  B01CTRH04K  average rating is  4.626373626373627
# The first similar product is  B00J2L589Q  average rating is  4.597560975609756
# The second similar product is  B00J4YYMES  average rating is  4.55
# -----------------------------------------------------------
# Based on product reviews, for  B01CTZC4QQ  average rating is  4.3872340425531915
# The first similar product is  B00Q8JQKEC  average rating is  4.633620689655173
# The second similar product is  B00UB6UE7C  average rating is  4.274131274131274
# -----------------------------------------------------------
# Based on product reviews, for  B01CTZCFKQ  average rating is  4.604395604395604
# The first similar product is  B00PFL36PK  average rating is  4.656488549618321
# The second similar product is  B00T61S58S  average rating is  4.318181818181818
# -----------------------------------------------------------
# Based on product reviews, for  B01CTZCPB0  average rating is  4.6
# The first similar product is  B00I9KRX3A  average rating is  4.3580246913580245
# The second similar product is  B00I669J5W  average rating is  4.7682926829268295
# -----------------------------------------------------------
# Based on product reviews, for  B01CTZCYEI  average rating is  4.628865979381444
# The first similar product is  B00UTJK6J2  average rating is  4.587155963302752
# The second similar product is  B00TDEDS7Q  average rating is  4.871287128712871
# -----------------------------------------------------------
# Based on product reviews, for  B01D4G9PPM  average rating is  4.294117647058823
# The first similar product is  B00VWH6MM0  average rating is  4.325842696629214
# The second similar product is  B00OOWQ3C4  average rating is  4.425
# -----------------------------------------------------------
# Based on product reviews, for  B01D4G9UFM  average rating is  4.186991869918699
# The first similar product is  B00WYOFUAK  average rating is  3.984251968503937
# The second similar product is  B012W2ZQ34  average rating is  4.56
# -----------------------------------------------------------
# Based on product reviews, for  B01D4GAXN0  average rating is  4.249394673123486
# The first similar product is  B000OV4FY2  average rating is  4.219948849104859
# The second similar product is  B00R1J3N84  average rating is  4.414507772020725
# -----------------------------------------------------------
# Based on product reviews, for  B01D4GB11I  average rating is  3.8134328358208953
# The first similar product is  B00ZTNNNR0  average rating is  4.310861423220974
# The second similar product is  B00R1H0YCY  average rating is  4.33
# -----------------------------------------------------------
# Based on product reviews, for  B01DBCBXB8  average rating is  3.0987654320987654
# The first similar product is  B00SMYMTOG  average rating is  4.154761904761905
# The second similar product is  B00VWH6ITW  average rating is  3.5294117647058822
# -----------------------------------------------------------
# Based on product reviews, for  B01DLRDD3Y  average rating is  4.329268292682927
# The first similar product is  B012O4WHU0  average rating is  4.525
# The second similar product is  B00VWH6ITW  average rating is  3.5294117647058822
# -----------------------------------------------------------
# Based on product reviews, for  B01DW32TKK  average rating is  4.71830985915493
# The first similar product is  B00NJ1MALE  average rating is  4.660130718954249
# The second similar product is  B00I2X7KZA  average rating is  4.531914893617022
# -----------------------------------------------------------
# Based on product reviews, for  B01DW341DS  average rating is  4.415094339622642
# The first similar product is  B00RBPZN6S  average rating is  4.142857142857143
# The second similar product is  B00I9KRX3A  average rating is  4.3580246913580245
# -----------------------------------------------------------
# Based on product reviews, for  B01DXJ9PNC  average rating is  4.264705882352941
# The first similar product is  B0111K05XO  average rating is  4.512605042016807
# The second similar product is  B00V78208Y  average rating is  4.366336633663367
# -----------------------------------------------------------
# Based on product reviews, for  B01DZKCLB2  average rating is  4.3
# The first similar product is  B00O33F8N4  average rating is  4.5227272727272725
# The second similar product is  B00UT49KPS  average rating is  3.9047619047619047
# -----------------------------------------------------------
# Based on product reviews, for  B01DZX5M8S  average rating is  4.283950617283951
# The first similar product is  B00Z9ZUT8E  average rating is  4.134146341463414
# The second similar product is  B00V1OFAN6  average rating is  4.481481481481482
# -----------------------------------------------------------
# Based on product reviews, for  B01E3VJ8L8  average rating is  4.735294117647059
# The first similar product is  B010NE61XM  average rating is  4.518072289156627
# The second similar product is  B00PC5D6GS  average rating is  4.276190476190476
# -----------------------------------------------------------
# Based on product reviews, for  B01E766EK2  average rating is  4.4409090909090905
# The first similar product is  B00I669LU0  average rating is  4.487804878048781
# The second similar product is  B011O4YWQS  average rating is  4.377049180327869
# -----------------------------------------------------------
# Based on product reviews, for  B01ERBUCM8  average rating is  4.72093023255814
# The first similar product is  B000PUIPXO  average rating is  4.228571428571429
# The second similar product is  B0010YWJYK  average rating is  4.240384615384615
# -----------------------------------------------------------
# Based on product reviews, for  B01ERBVHVI  average rating is  4.742574257425742
# The first similar product is  B016KZU47C  average rating is  4.783132530120482
# The second similar product is  B00UT3YLKS  average rating is  4.566037735849057
# -----------------------------------------------------------
# Based on product reviews, for  B01EUIHPEG  average rating is  4.479591836734694
# The first similar product is  B00HZYBXUK  average rating is  4.474226804123711
# The second similar product is  B00JSC9HNW  average rating is  4.695238095238095
# -----------------------------------------------------------
# Based on product reviews, for  B01F6UTLIK  average rating is  4.61344537815126
# The first similar product is  B00Z9YWAO6  average rating is  4.434782608695652
# The second similar product is  B00IT70V8C  average rating is  4.626016260162602
# -----------------------------------------------------------
# Based on product reviews, for  B01FE3T45E  average rating is  4.525114155251141
# The first similar product is  B015IP43MW  average rating is  4.647342995169082
# The second similar product is  B00R1H0438  average rating is  4.571428571428571
# -----------------------------------------------------------
# Based on product reviews, for  B01FRJ1FZ2  average rating is  4.609756097560975
# The first similar product is  B015GK13QS  average rating is  4.494252873563219
# The second similar product is  B015GK0Z8A  average rating is  4.325
# -----------------------------------------------------------
# Based on product reviews, for  B01FUB9XMY  average rating is  4.618962432915922
# The first similar product is  B000OV4FY2  average rating is  4.219948849104859
# The second similar product is  B00HZYD5KQ  average rating is  4.461734693877551
# -----------------------------------------------------------
# Based on product reviews, for  B01FUD3CC4  average rating is  3.4232804232804233
# The first similar product is  B00OKKMHIO  average rating is  3.1605839416058394
# The second similar product is  B00O7TNRMS  average rating is  3.9398496240601504
# -----------------------------------------------------------
# Based on product reviews, for  B01FUGTHBG  average rating is  4.098765432098766
# The first similar product is  B00SFCKDM0  average rating is  4.725
# The second similar product is  B00QJGS0OM  average rating is  3.849462365591398
# -----------------------------------------------------------
# Based on product reviews, for  B01G3N472O  average rating is  4.2155688622754495
# The first similar product is  B00SMYSO3Q  average rating is  4.380952380952381
# The second similar product is  B0111K3QI0  average rating is  4.486725663716814
# -----------------------------------------------------------
# Based on product reviews, for  B01G3N49LI  average rating is  4.175925925925926
# The first similar product is  B00V1P7V0A  average rating is  4.282828282828283
# The second similar product is  B00VHNVIUK  average rating is  4.258426966292135
# -----------------------------------------------------------
# Based on product reviews, for  B01G3N4C06  average rating is  4.2926829268292686
# The first similar product is  B00VG37VE8  average rating is  3.9871794871794872
# The second similar product is  B011B6RSXI  average rating is  4.023255813953488
# -----------------------------------------------------------
# Based on product reviews, for  B01G56IV4Y  average rating is  4.4033613445378155
# The first similar product is  B0111K05XO  average rating is  4.512605042016807
# The second similar product is  B00Z9YWAO6  average rating is  4.434782608695652
# -----------------------------------------------------------
# Based on product reviews, for  B01G56JCGU  average rating is  4.305555555555555
# The first similar product is  B00I669J5W  average rating is  4.7682926829268295
# The second similar product is  B00OP1227O  average rating is  4.494623655913978
# -----------------------------------------------------------
# Based on product reviews, for  B01G6I57WA  average rating is  4.375
# The first similar product is  B00X80345W  average rating is  4.008130081300813
# The second similar product is  B011B6PXVW  average rating is  4.38135593220339
# -----------------------------------------------------------
# Based on product reviews, for  B01GCNSGRW  average rating is  3.875
# The first similar product is  B00V1PAQZW  average rating is  4.4941176470588236
# The second similar product is  B00X3G7GUK  average rating is  4.346938775510204
# -----------------------------------------------------------
# Based on product reviews, for  B01H1I2P7Y  average rating is  4.1629955947136565
# The first similar product is  B00NAZ5MUA  average rating is  4.447619047619048
# The second similar product is  B00MW3HE98  average rating is  4.270531400966184
# -----------------------------------------------------------
# Based on product reviews, for  B01H5GB8ZW  average rating is  4.528497409326425
# The first similar product is  B00WFVWK2S  average rating is  4.635802469135802
# The second similar product is  B00IAE5VSY  average rating is  4.220994475138122
# -----------------------------------------------------------
# Based on product reviews, for  B01H6JE562  average rating is  4.684782608695652
# The first similar product is  B00V1P7V0A  average rating is  4.282828282828283
# The second similar product is  B00O0ZUZVA  average rating is  4.321428571428571
# -----------------------------------------------------------
# Based on product reviews, for  B01H6OXQFS  average rating is  4.63030303030303
# The first similar product is  B00UB6E4IM  average rating is  4.557788944723618
# The second similar product is  B010CRG27K  average rating is  4.694267515923567
# -----------------------------------------------------------
# Based on product reviews, for  B01HEZ9F68  average rating is  3.9615384615384617
# The first similar product is  B00UB77PQO  average rating is  4.295454545454546
# The second similar product is  B00V1P7V0A  average rating is  4.282828282828283
# -----------------------------------------------------------
# Based on product reviews, for  B01HEZAEIG  average rating is  4.114583333333333
# The first similar product is  B010NBFHFS  average rating is  4.287356321839081
# The second similar product is  B00V1O9F5U  average rating is  4.146341463414634
# -----------------------------------------------------------
# Based on product reviews, for  B01HEZAI00  average rating is  4.447916666666667
# The first similar product is  B00V1O9F5U  average rating is  4.146341463414634
# The second similar product is  B013QN6SNA  average rating is  4.465116279069767
# -----------------------------------------------------------
# Based on product reviews, for  B01HHVVLGQ  average rating is  3.9757281553398056
# The first similar product is  B0108CO6HC  average rating is  4.487654320987654
# The second similar product is  B00I9VCRJ4  average rating is  3.7745098039215685
# -----------------------------------------------------------
# Based on product reviews, for  B01HHVWWMI  average rating is  4.516483516483516
# The first similar product is  B010NBFHFS  average rating is  4.287356321839081
# The second similar product is  B016DHCJP2  average rating is  4.34375
# -----------------------------------------------------------

# %%
y_train = df_product_review["overall"][:len(X_train)].apply(np.ceil)
y_test = df_product_review["overall"][len(X_train):len(X_train)+len(X_test)].apply(np.ceil)

# %% [markdown]
# Over Sampling

# %%
#before over sampling
y_train.value_counts().sort_index().plot(kind='bar', color='lightcoral', figsize=(8, 6))
plt.xlabel('Overall Rating')
plt.ylabel('Number of Instances')
plt.title('Distribution of Overall Ratings in the Training Set', fontweight="bold")
plt.show()

# %% [markdown]
# ### Apply kNN

# %%
clf = neighbors.KNeighborsClassifier(3, weights='distance')
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
print(classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          3.0       0.00      0.00      0.00         1
#          4.0       0.40      0.09      0.15        22
#          5.0       0.83      0.98      0.90        92
#
#     accuracy                           0.80       115
#    macro avg       0.41      0.36      0.35       115
# weighted avg       0.74      0.80      0.74       115

# %%
print ("accuracy_score", accuracy_score(y_test, pred))
print("mean_squared_error" , mean_squared_error(y_test, pred))
# Out:
# accuracy_score 0.8
# mean_squared_error 0.2

# %%
cluster = df.groupby("overall")["summary"].apply(list)
cluster = pd.DataFrame(cluster)
cluster.to_csv("cluster.csv")
cluster1 = pd.read_csv("cluster.csv")
cluster1["summaryClean"] = cluster1["summary"].apply(cleanText)

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=500,
        max_font_size=30, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin; it was heads
    ).generate(str(data))
    
    fig = plt.figure(1, figsize=(8, 8))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

# %% [markdown]
# Generates a word cloud for reviews with a specific score.

# %%
show_wordcloud(cluster1["summaryClean"][0], title = "Review Score One")

# %%
show_wordcloud(cluster1["summaryClean"][1], title = "Review Score Two")

# %%
show_wordcloud(cluster1["summaryClean"][2], title = "Review Score 3")

# %%
show_wordcloud(cluster1["summaryClean"][3], title = "Review Score 4")

# %%
show_wordcloud(cluster1["summaryClean"][4], title = "Review Score 5")

# %% [markdown]
# Evaluates the error rate for different values of k in K-Nearest Neighbors.

# %%
errors = []
K = range(1,10)
for k in K:
    model  = neighbors.KNeighborsClassifier(n_neighbors=k, algorithm='kd_tree')
    model.fit(X_train,y_train)
    pred = model.predict(X_test)
    errors.append(mean_squared_error(y_test, pred))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,10), errors, color='lightcoral', linestyle='dashed', marker='o', markersize=10)
plt.title('Error Rate vs. K Value', fontweight="bold")
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
clf = neighbors.KNeighborsClassifier(9, weights='distance')
clf.fit(X_train, y_train)
pred = clf.predict(X_test)

print(classification_report(y_test, pred))
print ("Accuracy: ",accuracy_score(y_test, pred))
print("MSE: ",mean_squared_error(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          3.0       0.00      0.00      0.00         1
#          4.0       0.83      0.23      0.36        22
#          5.0       0.84      1.00      0.92        92
#
#     accuracy                           0.84       115
#    macro avg       0.56      0.41      0.42       115
# weighted avg       0.83      0.84      0.80       115
#
# Accuracy:  0.8434782608695652
# MSE:  0.1565217391304348
# /Users/fannypatel/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/fannypatel/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/fannypatel/anaconda3/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
